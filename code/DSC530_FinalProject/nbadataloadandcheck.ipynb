# %%
import pandas as pd
import glob

#Path is location of NBA Game logs on my computer after downloading from repository
#Repository location : https://github.com/ryanvmenezes/lawlers-law/tree/master/data/logs

path = r'C:\Users\Danny\Documents\data\proj' # use your path
all_files = glob.glob(path+ "\*.csv")

#Header refers to the position of Column Headers
#Axis determines whether it will be merged on rows or columns
frame = pd.concat(((pd.read_csv(f, index_col=None, header=0)) for f in all_files)
                  , axis=0, ignore_index=True)

# %%
frame.to_csv( "nbagames1985to2019.csv", index=False, encoding='utf-8-sig')

# %%
frame.head(2)
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 0      21985  1610612737               ATL       Atlanta Hawks  28500005
# 1      21985  1610612764               WAS  Washington Bullets  28500005
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  STL  BLK  TOV  \
# 0  1985-10-25  ATL vs. WAS  L  240   41  ...    28   44   25    8    5   16
# 1  1985-10-25    WAS @ ATL  W  240   40  ...    29   40   21   11    7   17
#
#    PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0  23   91          -9                0
# 1  19  100           9                0
#
# [2 rows x 29 columns]

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77886 entries, 0 to 77885
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEASON_ID          77886 non-null  int64
#  1   TEAM_ID            77886 non-null  int64
#  2   TEAM_ABBREVIATION  77886 non-null  object
#  3   TEAM_NAME          77886 non-null  object
#  4   GAME_ID            77886 non-null  int64
#  5   GAME_DATE          77886 non-null  object
#  6   MATCHUP            77886 non-null  object
#  7   WL                 77884 non-null  object
#  8   MIN                77886 non-null  int64
#  9   FGM                77886 non-null  int64
#  10  FGA                77886 non-null  int64
#  11  FG_PCT             77884 non-null  float64
#  12  FG3M               77886 non-null  int64
#  13  FG3A               77886 non-null  int64
#  14  FG3_PCT            77408 non-null  float64
#  15  FTM                77886 non-null  int64
# ...
